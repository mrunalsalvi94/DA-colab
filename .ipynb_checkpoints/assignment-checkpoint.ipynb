# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Example model data.xlsx")

# %%
df
# Out:
#        Channel  Spend (£)  Impressions   Clicks  Conversions  Revenue (£)  \
# 0   Google Ads     120000      5000000  45000.0         1200       240000
# 1     Meta Ads      90000      4200000  38000.0          950       180000
# 2           TV     200000     20000000      NaN         1500       300000
# 3  Display Ads      50000      3000000  20000.0          500       100000
# 4   TikTok Ads      75000      6000000  50000.0          800       160000
#
#    ROAS  mROAS  Carryover rate
# 0  2.00   1.65            0.11
# 1  3.75   4.95            0.32
# 2  1.35   2.30            0.78
# 3  2.00   2.10            0.48
# 4  2.10   3.25            0.22
